# %%
#판다스, 표
from pandas import DataFrame
from datetime import datetime
import numpy as np


#시각화
import matplotlib as mpl
import seaborn as sns; sns.set(style='darkgrid', font='malgun', font_scale=1.5)
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#표
import pandas as pd
import csv

#폰트 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %%
df = pd.read_excel('C:\\Users\\admin\\Downloads\\NewsResult.xlsx')

# %%
#timestamp 추가
df['timestamp'] = pd.to_datetime(df["일자"],format='%Y%m%d', errors='ignore')
df['timestamp']


#timestamp 3개로 나누기
df['year'] = df["timestamp"].dt.year
df['month'] = df["timestamp"].dt.month
df['day'] = df["timestamp"].dt.day

#날짜 str로 바꾸기 왠지몰라
df['year'] = df['year'].astype(int)
df['month'] = df['month'].astype(int)
df['day'] = df['day'].astype(int)
df
# Out:
#              뉴스 식별자        일자     언론사         기고자  \
# 0      2.100801e+06  20200413   아시아경제  호남취재본부 서영서
# 1      1.601001e+06  20200413  전북도민일보    총선 특별취재단
# 2      1.400401e+06  20200413    중부매일      박재원 기자
# 3      1.500601e+06  20200413    매일신문         유광준
# 4      1.400551e+06  20200413    충북일보         강준식
# ...             ...       ...     ...         ...
# 15731  1.500051e+06  20200113    경남신문         이종구
# 15732  1.500051e+06  20200113    경남신문         이종구
# 15733  1.500051e+06  20200113    경남신문         김희진
# 15734  2.100501e+06  20200113  파이낸셜뉴스         김은진
# 15735  1.600801e+06  20200113    전남일보         곽지혜
#
#                                                       제목    통합 분류1     통합 분류2  \
# 0                           목포대학교, 전남 동남권 의대 추진 움직임 ‘규탄’     지역>광주      지역>전남
# 1                           민생당, 시민당 한국당 위성정당 위헌소원 소장 접수  정치>국회_정당      정치>선거
# 2                                    총선 출판기념회 '노쇼' 완주 2명    정치>청와대      정치>선거
# 3      김종인 13일 대구 방문일정 취소, 통합당 지도부 '텃밭' 방문 없이 총선 선거운동...  정치>국회_정당      정치>선거
# 4                             충북소방본부, 안전한 21대 국회의원 선거 총력     지역>충북      지역>경남
# ...                                                  ...       ...        ...
# 15731                           [4 15 총선 누가 뛰나] (6) 김해시갑  정치>국회_정당      정치>선거
# 15732                            [4 15 총선 누가 뛰나] (7) 김해을  정치>국회_정당      정치>선거
# 15733               김해시선관위, 총선 예비후보 관련 책 배부 혐의 공선법 위반 고발     정치>선거   정치>국회_정당
# 15734                          [특별기고]지식재산권 체질 개선하는 한해 돼야  정치>국회_정당        NaN
# 15735                      박주선 5선 행보, 이병훈 김성환 등 거센 '도전장'     정치>선거   정치>국회_정당
#
#           통합 분류3 사건/사고 분류1 사건/사고 분류2  ...  \
# 0       사회>교육_시험       NaN       NaN  ...
# 1            NaN       NaN       NaN  ...
# 2       정치>국회_정당       NaN       NaN  ...
# 3            NaN       NaN       NaN  ...
# 4        사회>사회일반       NaN       NaN  ...
# ...          ...       ...       ...  ...
# 15731      정치>북한       NaN       NaN  ...
# 15732     정치>청와대       NaN       NaN  ...
# 15733   사회>사건_사고       NaN       NaN  ...
# 15734        NaN       NaN       NaN  ...
# 15735     정치>청와대       NaN       NaN  ...
#
#                                                       기관  \
# 0      의대,의과대학,민주당,목포대학교,집권당,민주연구원,보건사회연구원,국무총리실,목포대,교육부
# 2      - 충북 선거구 12월부터 11명 행사 본선까지 완주는 단 2명 \n \n［중부매일...
# 3      '주는 대로 먹어라!'식의 공천농단으로 텃밭 민심을 저버렸던 미래통합당이 4 15 ...
# 4      ［충북일보］ 충북소방본부가 21대 국회의원 선거가 진행되는 도내 투 개표소의 화재 ...
# ...                                                  ...
# 15731  도농 복합지역인 김해시는 갑 을로 분구되기 전인 2000년 16대 총선까지는 자유한...
# 15732  고 노무현 전 대통령의 고향인 봉하마을이 있는 김해을은 김해갑과 마찬가지로 갑 을 ...
# 15733  김해시선거관리위원회는 제21대 국회의원 선거 예비후보자와 관련된 책을 동호회 회원들...
# 15734  국민적 공분 산 '펭수 상표권' \n변리사 직업윤리에도 치명타 \n'펭수법'이 자정...
# 15735  광주 동구남구갑과 함께 지난 2016년 이후 광주 동구와 남구 일부 지역이 통합 신...
#
#                                                      URL 분석제외 여부  timestamp  \
# 0       http:www.asiae.co.kr/article/2020041317021677711     NaN 2020-04-13
# 1      http://www.domin.co.kr/news/articleView.html?i...     NaN 2020-04-13
# 2      http://www.jbnews.com/news/articleView.html?id...     NaN 2020-04-13
# 3      https://news.imaeil.com/Politics/2020041316484...     NaN 2020-04-13
# 4      https://www.inews365.com/news/article.html?no=...     NaN 2020-04-13
# ...                                                  ...     ...        ...
# 15731                                                NaN     NaN 2020-01-13
# 15732                                                NaN     NaN 2020-01-13
# 15733                                                NaN     NaN 2020-01-13
# 15734      http://www.fnnews.com/news/202001121823322894     NaN 2020-01-13
# 15735                                                NaN     NaN 2020-01-13
#
#        year month day
# 0      2020     4  13
# 1      2020     4  13
# 2      2020     4  13
# 3      2020     4  13
# 4      2020     4  13
# ...     ...   ...  ..
# 15731  2020     1  13
# 15732  2020     1  13
# 15733  2020     1  13
# 15734  2020     1  13
# 15735  2020     1  13
#
# [15736 rows x 23 columns]

# %%
#작은 테이블 만들기

new_df = df[['본문','키워드','year', 'day', 'month']]

new1 = new_df[new_df['본문'].str.match('총선') | new_df['키워드'].str.match('매일신문') ]
df_date = new1[(df["month"] >= 3) & (df["month"] <= 4) & (df["day"] >= 1)& (df["day"] <= 30)]
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      본문  키워드  year  month
# day
# 4     3    3     3      3
# 5     2    2     2      2
# 6     3    3     3      3
# 7     2    2     2      2
# 8     1    1     1      1
# 9     1    1     1      1
# 10    2    2     2      2
# 11    2    2     2      2
# 12    3    3     3      3
# 13    2    2     2      2
# 16    1    1     1      1
# 17    3    3     3      3
# 19    1    1     1      1
# 21    1    1     1      1
# 25    2    2     2      2
# 28    1    1     1      1

# %%
# **가 언급된 날짜별 기사건수 

graph = df_date.groupby(df_date["day"]).count()

x = graph.index
y = graph['본문']

f, ax = plt.subplots(figsize=(16,8)); plt.xticks(x, rotation=0)


ax = f.add_subplot(1,1,1) # Get the figure and the axes

ax.set(title='날짜별 기사건수', xlabel='날짜별', ylabel='기사량')

ax.errorbar(x, y, fmt = "ro-" ,capsize=2 ) 

plot = ax.bar(x, y)

for rect in plot:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2., height, '%d' %int(height), ha='center', va='bottom')
    plt.savefig('C:/Users/admin/Documents/IMG02.png', bbox_inches='tight')
